# %%
import pandas as pd

COVID_FILE_PATH = "covid-chestxray-dataset/metadata.csv"
COVID_IMAGES_PATH = "covid-chestxray-dataset/images/"

df_all = pd.read_csv(COVID_FILE_PATH)
print(df_all.shape)

df_all.head()
# Out:
# (950, 30)
#   patientid  offset sex   age                   finding RT_PCR_positive  \
# 0         2     0.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 1         2     3.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 2         2     5.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 3         2     6.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 4         4     0.0   F  52.0  Pneumonia/Viral/COVID-19               Y
#
#   survival intubated intubation_present went_icu  ...              date  \
# 0        Y         N                  N        N  ...  January 22, 2020
# 1        Y         N                  N        N  ...  January 25, 2020
# 2        Y         N                  N        N  ...  January 27, 2020
# 3        Y         N                  N        N  ...  January 28, 2020
# 4      NaN         N                  N        N  ...  January 25, 2020
#
#                                             location  folder  \
# ...

# %%
df_covid = df_all[df_all['finding'].str.contains('COVID-19')]
print(type(df_covid))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df_covid.head()
# Out:
#   patientid  offset sex   age                   finding RT_PCR_positive  \
# 0         2     0.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 1         2     3.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 2         2     5.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 3         2     6.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 4         4     0.0   F  52.0  Pneumonia/Viral/COVID-19               Y
#
#   survival intubated intubation_present went_icu  ...              date  \
# 0        Y         N                  N        N  ...  January 22, 2020
# 1        Y         N                  N        N  ...  January 25, 2020
# 2        Y         N                  N        N  ...  January 27, 2020
# 3        Y         N                  N        N  ...  January 28, 2020
# 4      NaN         N                  N        N  ...  January 25, 2020
#
#                                             location  folder  \
# ...

# %%
## There are 584 COVID-19 patients for whom we have chest X rays 
## Joining image with metadata

import os
import shutil

df_covid = df_covid[~df_covid['filename'].str.contains('.gz')]
# for (i, row) in df_covid.iterrows():
#     COVID_IMAGES_PATH = os.path.join('covid-chestxray-dataset/images', row['filename'])
#     PROCESSED_IMAGE_PATH = 'Processed dataset/'
#     image_copy = os.path.join(PROCESSED_IMAGE_PATH, row['filename'])
#     shutil.copy2(COVID_IMAGES_PATH, PROCESSED_IMAGE_PATH)

# %%
df_covid[df_covid['sex'] == 'F'].count()
# Out:
# patientid                 167
# offset                    138
# sex                       167
# age                       134
# finding                   167
# RT_PCR_positive           166
# survival                   77
# intubated                  64
# intubation_present         61
# went_icu                   88
# in_icu                     72
# needed_supplemental_O2     31
# extubated                   6
# temperature                23
# pO2_saturation             34
# leukocyte_count             4
# neutrophil_count            5
# lymphocyte_count            7
# view                      167
# modality                  167
# date                      128
# location                  166
# folder                    167
# filename                  167
# doi                        88
# url                       167
# license                   105
# clinical_notes            133
# other_notes                58
# Unnamed: 29                 0
# dtype: int64

# %%
df_covid.describe()
# Out:
#            offset         age  temperature  pO2_saturation  leukocyte_count  \
# count  431.000000  429.000000    63.000000       99.000000        14.000000
# mean     6.865429   56.636364    39.049206       76.891919         5.273571
# std      8.715423   16.545976     7.220644       38.795425         2.748397
# min     -7.000000   20.000000    36.000000       20.000000         0.220000
# 25%      1.000000   45.000000    37.600000       55.000000         3.135000
# 50%      5.000000   58.000000    38.100000       85.000000         5.935000
# 75%      9.000000   70.000000    38.950000       93.000000         6.892500
# max     72.000000   94.000000    95.000000      340.000000        11.200000
#
#        neutrophil_count  lymphocyte_count
# count         24.000000         36.000000
# mean           5.129167          4.967278
# std            3.580293         21.666671
# min            0.000000          0.400000
# 25%            2.425000          0.682500
# ...

# %%
import random
NORMAL_IMAGES_PATH = 'chest_xray/train/NORMAL/'
PROCESSED_IMAGE_PATH = 'Processed dataset/Normal/'

normal_images = os.listdir(NORMAL_IMAGES_PATH)

# %%
len(df_covid)
# Out:
# 563

# %%
random.shuffle(normal_images)

# %%
for i in range(len(df_covid)):
# for i in range(2):
    img = normal_images[i]
    NORMAL_IMAGES_PATH2 = os.path.join(NORMAL_IMAGES_PATH, img)
    PROCESSED_IMAGE_PATH2 = os.path.join(PROCESSED_IMAGE_PATH, img)
    print(NORMAL_IMAGES_PATH2 , "::  ")
    shutil.copy2(NORMAL_IMAGES_PATH2, PROCESSED_IMAGE_PATH2)
    print("copying image ", i)
# Out:
# chest_xray/train/NORMAL/IM-0620-0001-0002.jpeg ::
# copying image  0
# chest_xray/train/NORMAL/IM-0599-0001.jpeg ::
# copying image  1
# chest_xray/train/NORMAL/IM-0286-0001.jpeg ::
# copying image  2
# chest_xray/train/NORMAL/NORMAL2-IM-1281-0001.jpeg ::
# copying image  3
# chest_xray/train/NORMAL/NORMAL2-IM-0725-0001.jpeg ::
# copying image  4
# chest_xray/train/NORMAL/IM-0658-0001.jpeg ::
# copying image  5
# chest_xray/train/NORMAL/NORMAL2-IM-0687-0001.jpeg ::
# copying image  6
# chest_xray/train/NORMAL/IM-0185-0001.jpeg ::
# copying image  7
# chest_xray/train/NORMAL/NORMAL2-IM-0854-0001.jpeg ::
# copying image  8
# chest_xray/train/NORMAL/IM-0172-0001.jpeg ::
# copying image  9
# chest_xray/train/NORMAL/IM-0596-0001.jpeg ::
# copying image  10
# chest_xray/train/NORMAL/NORMAL2-IM-0851-0001.jpeg ::
# copying image  11
# chest_xray/train/NORMAL/IM-0553-0001-0003.jpeg ::
# copying image  12
# chest_xray/train/NORMAL/NORMAL2-IM-0413-0001.jpeg ::
# copying image  13
# ...
